# %% [markdown]
# #Training on Balanced SelfMA Dataset (dataset created by Carlos)

# %% [markdown]
# Then later we can simultaneously train on iSarcasm, following Neeha's work.
#
# First, upload the version of the dataset with quote plus text.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
#import dataset that includes quotes AND context

from datasets import load_from_disk

from google.colab import drive
drive.mount('/content/drive')

balanced_selfMA_ds_quotecontext = load_from_disk("/content/drive/MyDrive/266_project/balanced_selfMA_ds")

print(balanced_selfMA_ds_quotecontext)               # Dataset or DatasetDict
print(balanced_selfMA_ds_quotecontext.column_names)  # columns
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 4354
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 544
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 546
#     })
# })
# {'train': ['text', 'label'], 'validation': ['text', 'label'], 'test': ['text', 'label']}

# %%
for split, d in balanced_selfMA_ds_quotecontext.items():
        d.to_csv(f"/content/balanced_selfMA_ds_{split}.csv", index=False)
# Out:
# ...
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
train_quotecontext = pd.read_csv("/content/balanced_selfMA_ds_train.csv")
valid_quotecontext = pd.read_csv("/content/balanced_selfMA_ds_validation.csv")
test_quotecontext  = pd.read_csv("/content/balanced_selfMA_ds_test.csv")

# %%
balanced_selfMA_ds_train_quotecontext = pd.read_csv("/content/balanced_selfMA_ds_train.csv")

# %%
balanced_selfMA_ds_train_quotecontext.head()
# Out:
#                                                 text  label
# 0  "I don't understand how you actually have a ro...      1
# 1  "We'll give you this one, trust me Andre is no...      1
# 2  a comma is incredibly important it makes the d...      0
# 3  My co-worker went to Home Depot to buy a posth...      1
# 4  "That's ghetto!"  Said often by mainly white m...      1

# %%
import pandas as pd

frames = []
for split, dset in balanced_selfMA_ds_quotecontext.items():
    dset.reset_format()
    df = dset.to_pandas()
    df["split"] = split
    frames.append(df)

combined = pd.concat(frames, ignore_index=True)
combined.to_csv("/content/combined_micro.csv", index=False)

# %%
balanced_selfMA_ds_quotecontext = pd.read_csv("/content/combined_micro.csv")

# %%
balanced_selfMA_ds_quotecontext.head()
# Out:
#                                                 text  label  split
# 0  "I don't understand how you actually have a ro...      1  train
# 1  "We'll give you this one, trust me Andre is no...      1  train
# 2  a comma is incredibly important it makes the d...      0  train
# 3  My co-worker went to Home Depot to buy a posth...      1  train
# 4  "That's ghetto!"  Said often by mainly white m...      1  train

# %%
balanced_selfMA_ds_quotecontext["split"].value_counts()
# Out:
# split
# train         4354
# test           546
# validation     544
# Name: count, dtype: int64

# %%
balanced_selfMA_ds_quotecontext["label"].value_counts()
# Out:
# label
# 1    2722
# 0    2722
# Name: count, dtype: int64

# %%
#EDA
print(len(balanced_selfMA_ds_quotecontext))
# Out:
# 5444

# %%
#sanity check to make sure dataset includes both quote and context
matches = balanced_selfMA_ds_quotecontext[balanced_selfMA_ds_quotecontext["text"].str.contains("bipolar", case=False, na=False)]
matches
# Out:
#                                                    text  label       split
# 134   "I wish my son would dump the girl he's dating...      1       train
# 253   "You look normal."  When I tell people that I ...      1       train
# 1451                "People are so bipolar these days."      1       train
# 2230  "She's SO Bipolar, haha!"  Comments I usually ...      1       train
# 3427  My sister who has bipolar disorder cannot find...      1       train
# 3949  My first semester of college, my psych 101 pro...      1       train
# 4860  "She's a girl, of course she has mood swings."...      1  validation

# %% [markdown]
# Now upload version of dataset with just quote.

# %%
balanced_selfMA_ds_quoteonly = load_from_disk("/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly")

print(balanced_selfMA_ds_quoteonly)               # Dataset or DatasetDict
print(balanced_selfMA_ds_quoteonly.column_names)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2080
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 260
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 260
#     })
# })
# {'train': ['text', 'label'], 'validation': ['text', 'label'], 'test': ['text', 'label']}

# %%
balanced_selfMA_ds_quoteonly_test = load_from_disk("/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly/test")
balanced_selfMA_ds_quoteonly_validation = load_from_disk("/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly/validation")
balanced_selfMA_ds_quoteonly_train = load_from_disk("/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly/train")

# %%
#sanity check
print(balanced_selfMA_ds_quoteonly_test)
print(balanced_selfMA_ds_quoteonly_validation)
print(balanced_selfMA_ds_quoteonly_train)
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 260
# })
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 260
# })
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 2080
# })

# %%
#create csv of splits in the dataset as we did above

for split, d in balanced_selfMA_ds_quoteonly.items():
        d.to_csv(f"/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly_{split}.csv", index=False)
# Out:
# ...
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
train_quoteonly = pd.read_csv("/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly_train.csv")
valid_quoteonly = pd.read_csv("/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly_validation.csv")
test_quoteonly  = pd.read_csv("/content/drive/MyDrive/266_project/balanced_selfMA_ds_quoteonly_test.csv")

# %%
#from datasets import Dataset, DatasetDict
#ds_quoteonly = DatasetDict({
   # "train": Dataset.from_pandas(train_quoteonly),
   # "validation": Dataset.from_pandas(valid_quoteonly),
   # "test": Dataset.from_pandas(test_quoteonly),
#})

# %%
frames = []
for split, dset in balanced_selfMA_ds_quoteonly.items():
    dset.reset_format()
    df = dset.to_pandas()
    df["split"] = split
    frames.append(df)

combined = pd.concat(frames, ignore_index=True)
combined.to_csv("/content/combined_micro_quoteonly.csv", index=False)

# %%
balanced_selfMA_ds_quoteonly = pd.read_csv("/content/combined_micro_quoteonly.csv")

# %%
balanced_selfMA_ds_quoteonly.head()
# Out:
#                                                 text  label  split
# 0  Most comedians say Michael J. Fox is an easy t...      0  train
# 1  "I didn't watch the halftime show because she ...      1  train
# 2  "I have lots of sympathy for women, but I have...      1  train
# 3  "Are you sure you are alright with driving a s...      1  train
# 4  always remind myself nothing product about ins...      0  train

# %%
print(len(balanced_selfMA_ds_quoteonly))
# Out:
# 2600

# %% [markdown]
# #Training

# %%
#imports
# !pip -q install transformers accelerate datasets evaluate scikit-learn
import numpy as np
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split
from datasets import load_dataset, Dataset, DatasetDict



import transformers
import evaluate

# !pip install -q torchinfo
from torchinfo import summary

from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification
from transformers import TrainingArguments, Trainer

# %%
#use modernBERT for these experiments since we have lengthy entries
# !pip install -U transformers




model_checkpoint_name = "answerdotai/ModernBERT-base"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint_name)
modernbert_classification_model = AutoModelForSequenceClassification.from_pretrained(
    model_checkpoint_name,
    num_labels=2)
# Out:
# ...
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at answerdotai/ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#tokenize text


max_len = 510  # you can bump this for long context models

def tokenize_batch(batch):
    enc = tokenizer(
        batch["text"],
        max_length=max_len,
        padding="max_length",
        truncation=True,
        return_attention_mask=True,
        # DO NOT return_tensors here when using .map
    )
    enc["labels"] = batch["label"]
    return enc

train_tok = balanced_selfMA_ds_quoteonly_train.map(tokenize_batch, batched=True, remove_columns=balanced_selfMA_ds_quoteonly_train.column_names)
val_tok   = balanced_selfMA_ds_quoteonly_validation.map(tokenize_batch,   batched=True, remove_columns=balanced_selfMA_ds_quoteonly_validation.column_names)
test_tok  = balanced_selfMA_ds_quoteonly_test.map(tokenize_batch,  batched=True, remove_columns=balanced_selfMA_ds_quoteonly_test.column_names)

# Tell datasets to give Trainer torch tensors for these columns
cols = ["input_ids", "attention_mask", "labels"]
train_tok.set_format(type="torch", columns=cols)
val_tok.set_format(type="torch", columns=cols)
test_tok.set_format(type="torch", columns=cols)

# ---- Metrics ----
accuracy = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": accuracy.compute(predictions=preds, references=labels)["accuracy"]}
# Out:
# ...
# Map:   0%|          | 0/260 [00:00<?, ? examples/s]
# ...

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="/content/quoteonly_out",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    learning_rate=2e-5,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    report_to="none",
    fp16=True,
)

trainer = Trainer(
    model=modernbert_classification_model,
    args=training_args,
    train_dataset=train_tok,
    eval_dataset=val_tok,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='390' max='390' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [390/390 05:59, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.126000</td>
#       <td>0.040119</td>
#       <td>0.992308</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.026200</td>
#       <td>0.048646</td>
#       <td>0.988462</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.011300</td>
#       <td>0.029251</td>
#       <td>0.996154</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %%
#test on test data
pred = trainer.predict(test_tok)
test_preds = np.argmax(pred.predictions, axis=1)
test_labels = np.array(test_tok["labels"])

from sklearn.metrics import accuracy_score, classification_report
print("Test accuracy:", accuracy_score(test_labels, test_preds))

# If you know your label names (0/1 -> Normal/Microaggression):
target_names = ["Normal Speech", "Microaggression"]
print(classification_report(test_labels, test_preds, target_names=target_names))
# Out:
# Test accuracy: 0.9961538461538462
#                  precision    recall  f1-score   support
#
#   Normal Speech       0.99      1.00      1.00       130
# Microaggression       1.00      0.99      1.00       130
#
#        accuracy                           1.00       260
#       macro avg       1.00      1.00      1.00       260
#    weighted avg       1.00      1.00      1.00       260
